# %%
#First all the required modules form the tkinter library are imported
from tkinter import *
from tkinter import messagebox #Messagebox module is imported from the tkinter library
import numpy as np # The 'Numpy' library is imported to deal with arrays and data
import pandas as pd # The 'Pandas' libraru is imported to deal with the datasets 

# A list is declared to store all possible symptoms in consideration and also this is used for taking previously(if any) occured symptoms or health problems
l1=['itching','skin_rash','nodal_skin_eruptions','continuous_sneezing','shivering','chills','joint_pain',
    'stomach_pain','acidity','ulcers_on_tongue','muscle_wasting','vomiting','burning_micturition','spotting_ urination','fatigue',
    'weight_gain','anxiety','cold_hands_and_feets','mood_swings','weight_loss','restlessness','lethargy','patches_in_throat',
    'irregular_sugar_level','cough','high_fever','sunken_eyes','breathlessness','sweating','dehydration','indigestion',
    'headache','yellowish_skin','dark_urine','nausea','loss_of_appetite','pain_behind_the_eyes','back_pain','constipation',
    'abdominal_pain','diarrhoea','mild_fever','yellow_urine','yellowing_of_eyes','acute_liver_failure','fluid_overload',
    'swelling_of_stomach','swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
    'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs','fast_heart_rate',
    'pain_during_bowel_movements','pain_in_anal_region','bloody_stool','irritation_in_anus','neck_pain','dizziness','cramps',
    'bruising','obesity','swollen_legs','swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
    'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips','slurred_speech','knee_pain','hip_joint_pain',
    'muscle_weakness','stiff_neck','swelling_joints','movement_stiffness','spinning_movements','loss_of_balance','unsteadiness','weakness_of_one_body_side',
    'loss_of_smell','bladder_discomfort','foul_smell_of urine','continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
    'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain','abnormal_menstruation','dischromic _patches',
    'watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum','rusty_sputum','lack_of_concentration','visual_disturbances',
    'receiving_blood_transfusion','receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen','history_of_alcohol_consumption',
    'fluid_overload','blood_in_sputum','prominent_veins_on_calf','palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
    'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose','yellow_crust_ooze']
# A list of all the possible diseases that have been taken into consideration as plausible , is declared.
disease=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
        'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
        ' Migraine','Cervical spondylosis',
        'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']
#An empty list is declared to iterate over the indexes of the first list and append 0 each time
l2=[]
for x in range(0,len(l1)):
    l2.append(0)

# The test dataset 'Testing.csv' is loaded into a pandas dataframe called 'tr'-
tr=pd.read_csv("Testing.csv")
tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)# this replaces certain values in the 'prognosis' column of the DataFrame 'tr'.
#More specifically ,, it maps string labels of diseases like 'Fungal infection to 0 , 'Allergy' to 1 and so on.

X_test= tr[l1]   #this 'X_test' is created by selection of certain columns from 'tr' DataFrame, and the columns selected are those listed in the list 'l1',which contains symptom names . 
#Basically , this line extracts features (here symptoms) the the model will use to make predictions.
y_test = tr[["prognosis"]] #This is to select 'Prognosis' column from 'tr' and store in y_test.
#y_test is used as target(or label) for test data.
np.ravel(y_test)# This is used to convert the 'y_test' DataFrame column into a one-dimensional numoy array.

# The training data is loaded as a dataframe 'df'. 
df=pd.read_csv("Training.csv")
#The below code is for same purpose as in test data , that the different strings are mapped as numbers for effective execution by the model as it is more efficient to deal with numbers.
df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)
#This is to extract the columns specified in list 'l1' from the DataFrame 'df' to create 'X'.
X= df[l1]
#The list 'l1' included the name of symptoms and previously occured diseases or heallth problems, which makes 'X' the feature matrix for training data where every column represents a symptom and every row represetns a specific sample.
y = df[["prognosis"]]#'y' is assigned values from 'prognosis' column of 'df'. This serves as target for training data
np.ravel(y)#Again , this converts 'y' DataFrame column into one dimensional numpy array.

#To check if atleast one symptom is selected by the user-
def message():
    if (Symptom1.get() == "None" and  Symptom2.get() == "None" and Symptom3.get() == "None" and PastDisease1.get() == "None" and PastDisease2.get() == "None"):
        messagebox.showinfo("Enter atleast one symptom please")
    else :
        NaiveBayes()

def NaiveBayes():
    from sklearn.naive_bayes import MultinomialNB #Importing the 'MultinomialNB' class from 'sklearn' and fitting a Naive Bayes classifier to training data ('X' and 'y')
    gnb = MultinomialNB()#Naive Bayes classifier is initialized and assigned to this variable 'gnb'
    gnb=gnb.fit(X,np.ravel(y))#Fitting the Naive Bayes model using training data 'X' and the target labels 'y'
    from sklearn.metrics import accuracy_score# 'accuracy_score' function from 'sklearn.metrics' , which is for evaluating the accuracy of the model
    y_pred = gnb.predict(X_test)#Using the trained model 'gnb' to make predictions on test data 'X_test'
    print(accuracy_score(y_test, y_pred))#printing the accuracy of the predictions , which is in proportion to the test cases correctly predicted by the model
    print(accuracy_score(y_test, y_pred, normalize=False))#printing total number of correct predictions made out of the total test cases

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),PastDisease1.get(),PastDisease2.get()]
    #obtaining the user-entered symptom values from the GUI and storing them in list

    #Iterating over the indices of list l1-
    for k in range(0,len(l1)):
        for z in psymptoms:  #nested loop inorder to iterate over each symptomenterred by the user
            if(z==l1[k]): #chacking if the current-user entered symptom matches the symptom 
                l2[k]=1   #if match is found , setting the corresponding index in 'l2' to '1' indicating presence of symptom 

    inputtest = [l2]# A new symptom/previous history list 'l2' as input for prediction
    predict = gnb.predict(inputtest)#predicting using the trained Naive Bayes model
    predicted=predict[0]#Extracting the very first prediction from results

    h='no'#initializing a variable to track if a disease matching was found
    for a in range(0,len(disease)):
        if(disease[predicted] == disease[a]):
            h='yes' #changing to yes incase the disease is found
            break

    if (h=='yes'):
        t3.delete("1.0", END)#clearing the text box 't3' in the GUI
        t3.insert(END, disease[a])#inserting the name of diagnosed disease into the text box
    else:
        t3.delete("1.0", END)#clears the text box , and displays 'No Disease' which means no disease could be predicted
        t3.insert(END, "No Disease")

root = Tk()#To declare a main window
root.title("Symptom Based Disease Prediction") #this is for the name/title of the main window basically
root.configure(background='light blue')#the background of the main window is set to light blue

Symptom1 = StringVar()#declaring different string variables through the special Stringvar() function for tkinter
Symptom1.set(None) # by default the value of the variable is set to 'none' , the user shall be able to choose according to their will for the value.
Symptom2 = StringVar()
Symptom2.set(None)
Symptom3 = StringVar()
Symptom3.set(None)
PastDisease1 = StringVar()
PastDisease1.set(None)
PastDisease2 = StringVar()
PastDisease2.set(None)

w2 = Label(root, justify=LEFT, text="Disease Prediction Based On History And Symptoms",background="light green")#the Title inside the window is this and the text within the label is justified to the left side of the label area
w2.config(font=("Georgia", 20))#the font Georgia is used here.
w2.grid(row=1, column=0, columnspan=2, padx=500)#the text is in the alignment of the first row , in column 0 and occupies a span of column for 2 columns.
#There is horizontal padding of 570 px (padx=570) which helps center the label in the window by adding space on both sides.

S1Lb = Label(root, text="1st Symptom", background='light cyan', foreground='black')#this creates a label widget in root window where the label displays the text-"1st symptom"
S1Lb.config(font=("Arial", 15))#this sets the font style and size of text displayed in the 'S1Lb" label as created in above line
S1Lb.grid(row=11, column=1, pady=10, sticky=W)#this places the "S1lb" label in grid layout of 'root' window


S2Lb = Label(root,  text="2nd Symptom",background='light cyan',foreground='black')#similar to previous, it creates a label widget in root window,displaying "2nd symptom"
S2Lb.config(font=("Arial", 15))#this sets the font style and size of text 
S2Lb.grid(row=12, column=1, pady=10, sticky=W)#this places the "S2Lb" label in grid layout of 'root' window

S3Lb = Label(root,  text="3rd Symptom",background='light cyan',foreground='black')#similar to previous
S3Lb.config(font=("Arial", 15))
S3Lb.grid(row=13, column=1, pady=10, sticky=W)#the row 13 of the grid system is used here

S4Lb = Label(root,  text="Past History Of Disease(Minor or None)",background="light cyan",foreground='black')#similar to previous
S4Lb.config(font=("Arial", 15))
S4Lb.grid(row=14, column=1, pady=10, sticky=W)#the row 14 of the grid system is used here

S5Lb = Label(root,  text="Past History Of Disease(Major or None)",background="light cyan",foreground='black')#similar to previous
S5Lb.config(font=("Arial", 15))
S5Lb.grid(row=15, column=1, pady=10, sticky=W)#the row 15 of the grid system is used here

lr = Button(root, text="Predict",height=2, width=20, command=message,background="red")#
lr.config(font=("Helvetica", 15))
lr.grid(row=20, column=1,pady=20)

OPTIONS = sorted(l1)#to store the sorted form of the list l1 , and to be used for the dropdown menus

S1En = OptionMenu(root, Symptom1,*OPTIONS)#to create dropdown menu for symptom1
S1En.grid(row=11, column=2)

S2En = OptionMenu(root, Symptom2,*OPTIONS)#to create dropdown menu for symptom2
S2En.grid(row=12, column=2)

S3En = OptionMenu(root, Symptom3,*OPTIONS)#to create dropdown menu for symptom3
S3En.grid(row=13, column=2)

S4En = OptionMenu(root, PastDisease1,*OPTIONS)#to create dropdown menu for PastDisease1
S4En.grid(row=14, column=2)

S5En = OptionMenu(root, PastDisease2,*OPTIONS)#to create dropdown menu for PastDisease2
S5En.grid(row=15, column=2)

#This is for the text displaying the prediction 
t3 = Text(root, height=2, width=30)
t3.config(font=("Times New Roman", 20))
t3.grid(row=25, column=1 , padx=10)

# Atleast 3 column space is there for the layout, and to align the text below the title to the centre-
w2.grid(row=1, column=0, columnspan=3, sticky='EW')

S1Lb.grid(row=11, column=1, pady=10, sticky='EW')
S2Lb.grid(row=12, column=1, pady=10, sticky='EW')
S3Lb.grid(row=13, column=1, pady=10, sticky='EW')
S4Lb.grid(row=14, column=1, pady=10, sticky='EW')
S5Lb.grid(row=15, column=1, pady=10, sticky='EW')

lr.grid(row=20, column=1, pady=20, sticky='EW')

S1En.grid(row=11, column=2, sticky='W')  # Aligning the OptionMenus to the west of column 2 to line up under labels
S2En.grid(row=12, column=2, sticky='W')
S3En.grid(row=13, column=2, sticky='W')
S4En.grid(row=14, column=2, sticky='W')
S5En.grid(row=15, column=2, sticky='W')

t3.grid(row=25, column=1, padx=10, columnspan=2, sticky='EW')


root.mainloop()
# Out:
# 1.0
# 41
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# 1.0
# 41
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
